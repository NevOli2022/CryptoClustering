# %%
# Import required libraries and dependencies
import pandas as pd
import hvplot.pandas
import holoviews as hv
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
# Load the data into a Pandas DataFrame
df_market_data = pd.read_csv(
    "Resources/crypto_market_data.csv",
    index_col="coin_id")

# Display sample data
df_market_data.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %%
# Generate summary statistics
df_market_data.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %%
# Plot your data to see what's in your DataFrame
df_market_data.hvplot.line(
    width=800,
    height=400,
    rot=90
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [coin_id]   (value)

# %% [markdown]
# ---

# %% [markdown]
# ### Prepare the Data

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
# Reset index temporarily to access 'coin_id' if it was already set as the index
df_market_data.reset_index(inplace=True)

# Extract the columns to scale (excluding 'coin_id')
scale_columns = df_market_data.columns[1:]

# Initialize the StandardScaler
scaler_init = StandardScaler()

# Scale the data
scaled_data = scaler_init.fit_transform(df_market_data[scale_columns])

# %%
# Create a DataFrame with the scaled data
scaled_df = pd.DataFrame(scaled_data, columns=scale_columns)

# Copy the crypto names from the original DataFrame
scaled_df['coin_id'] = df_market_data['coin_id']

# Set the coin_id column as index
scaled_df = scaled_df.set_index('coin_id')

# Display the scaled DataFrame
scaled_df.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Original Scaled DataFrame.

# %%
# Create a list with the number of k-values from 1 to 11
k_values = list(range(1, 11))

# %%
# Create an empty list to store the inertia values
inertia_values = []

# Create a for loop to compute the inertia with each possible value of k
for k in k_values:
# 1. Create a KMeans model using the loop counter for the n_clusters
    kmeans = KMeans(n_clusters=k, random_state=42) 
# 2. Fit the model to the data using `df_market_data_scaled`
    kmeans.fit(scaled_df)
# 3. Append the model.inertia_ to the inertia list
    inertia_values.append(kmeans.inertia_)
# Out:
# c:\Users\mackd\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\mackd\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\mackd\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
# Create a dictionary with the data to plot the Elbow curve the different values of k to visually identify the optimal value for k.
elbowcurve_data = {'k': k_values, 'inertia': inertia_values}
elbowcurve_df = pd.DataFrame(elbowcurve_data)
elbowcurve_df
# Out:
#     k     inertia
# 0   1  287.000000
# 1   2  212.123342
# 2   3  170.193571
# 3   4   79.022435
# 4   5   71.097914
# 5   6   66.108827
# 6   7   54.488123
# 7   8   43.224693
# 8   9   32.860884
# 9  10   28.404885

# %%
# Plot a line chart with all the inertia values computed with the different values of k to visually identify the optimal value for k.
elbowcurve_df.hvplot('k','inertia')
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the best value for `k`?
#
# **Answer:** I think its about 4

# %% [markdown]
# ---

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Scaled DataFrame

# %%
# Initialize the K-Means model using the best value for k
kmeans_model = KMeans(n_clusters=4, random_state=42)

# %%
# Fit the K-Means model using the scaled DataFrame
kmeans_model.fit(scaled_df)
# Out:
# c:\Users\mackd\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4, random_state=42)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled DataFrame
crypto_clusters=kmeans_model.predict(scaled_df)

# Print the resulting array of cluster values.
crypto_clusters
# Out:
# array([0, 0, 2, 2, 0, 0, 0, 0, 0, 2, 2, 2, 2, 0, 2, 0, 2, 2, 0, 2, 2, 0,
#        2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 3, 0, 2, 2, 1, 2, 2, 2, 2])

# %%
# Create a copy of the scaled DataFrame
crypto_cluster_df = scaled_df.copy()

# %%
# Add a new column to the copy of the scaled DataFrame with the predicted clusters
crypto_cluster_df['Clusters'] = crypto_clusters
# Display the copy of the scaled DataFrame
crypto_clusters
# Out:
# array([0, 0, 2, 2, 0, 0, 0, 0, 0, 2, 2, 2, 2, 0, 2, 0, 2, 2, 0, 2, 2, 0,
#        2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 3, 0, 2, 2, 1, 2, 2, 2, 2])

# %%
# Create a scatter plot using hvPlot by setting
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`.
# Color the graph points with the labels found using K-Means and
# add the crypto name in the `hover_cols` parameter to identify
# the cryptocurrency represented by each data point.
crypto_cluster_df.hvplot.scatter(x="price_change_percentage_24h",y="price_change_percentage_7d",by='Clusters')
# Out:
# :NdOverlay   [Clusters]
#    :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d)

# %% [markdown]
# ---

# %% [markdown]
# ### Optimize Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`.
pca_model = PCA(n_components=3)

# %%
# Use the PCA model with `fit_transform` to reduce the original scaled DataFrame
# down to three principal components.
scaled_pca=pca_model.fit_transform(scaled_df)

# View the scaled PCA data
print(scaled_pca)
# Out:
# [[-0.60066733  0.84276006  0.46159457]
#  [-0.45826071  0.45846566  0.95287678]
#  [-0.43306981 -0.16812638 -0.64175193]
#  [-0.47183495 -0.22266008 -0.47905316]
#  [-1.15779997  2.04120919  1.85971527]
#  [-0.51653377  1.38837748  0.80407131]
#  [-0.45071134  0.51769912  2.84614316]
#  [-0.34559977  0.72943939  1.47801284]
#  [-0.64946792  0.43216514  0.60030286]
#  [-0.75901394 -0.20119979 -0.21765292]
#  [-0.24819846 -1.37625159 -1.46202571]
#  [-0.43840762 -0.17533654 -0.6633884 ]
#  [-0.69342533 -0.47381462 -0.52759693]
#  [ 0.06049915  2.90940385  1.49857131]
#  [-0.39335243 -0.10819197 -0.01275608]
#  [-0.79617564 -0.49440875  1.08281169]
#  [ 0.06407452 -1.26982514 -1.09882928]
#  [-0.48901506 -0.73271912 -0.06254323]
#  [-0.3062723   0.70341515  1.71422359]
#  [-0.51352775 -0.14280239 -0.65656583]
#  [-0.36212044 -0.98691441 -0.72875232]
#  [-0.60426463  0.82739764  0.43931594]
#  [-0.4132956  -0.67411527 -1.07662834]
#  [-0.40748304 -0.21250655 -0.35142563]
# ...

# %%
# Retrieve the explained variance to determine how much information
# can be attributed to each principal component.

print(pca_model.explained_variance_)
# Out:
# [2.6689967  2.48978331 1.26307212]

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer:** 6.421852139197311

# %%
# Create a new DataFrame with the PCA data.
pca_data_df =  pd.DataFrame(scaled_pca, columns=["pca1","pca2","pca3"])

# Copy the crypto names from the original scaled DataFrame
# Set the coin_id column as index
pca_data_df = pca_data_df.set_index(scaled_df.index)

# Display the scaled PCA DataFrame
pca_data_df.head()
# Out:
#                   pca1      pca2      pca3
# coin_id
# bitcoin      -0.600667  0.842760  0.461595
# ethereum     -0.458261  0.458466  0.952877
# tether       -0.433070 -0.168126 -0.641752
# ripple       -0.471835 -0.222660 -0.479053
# bitcoin-cash -1.157800  2.041209  1.859715

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Scaled PCA DataFrame

# %%
# Create a list with the number of k-values from 1 to 11
k_values = list(range(1,11))

# %%
# Create an empty list to store the inertia values
inertia_values = []

# Step Create a for loop to compute the inertia with each possible value of k
for k in k_values:
    # Create a KMeans model using the loop counter for the n_clusters
    kmeans = KMeans(n_clusters=k, random_state=42)
    
    # Fit the model to the PCA data
    kmeans.fit(pca_data_df)
    
    # Append the model.inertia_ to the inertia list
    inertia_values.append(kmeans.inertia_)
# Out:
# c:\Users\mackd\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\mackd\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\mackd\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
# Create a dictionary with the data to plot the Elbow curve
pca_elbow = {'k': k_values, 'inertia': inertia_values}

# Create a DataFrame with the data to plot the Elbow curve
pca_elbow_df = pd.DataFrame(pca_elbow)
pca_elbow_df
# Out:
#     k     inertia
# 0   1  256.874086
# 1   2  182.339530
# 2   3  140.431833
# 3   4   49.665497
# 4   5   42.051901
# 5   6   31.749005
# 6   7   28.031869
# 7   8   19.451747
# 8   9   13.814082
# 9  10   10.630648

# %%
# Plot a line chart with all the inertia values computed with
# the different values of k to visually identify the optimal value for k.
pca_elbow_df.hvplot.line('k','inertia')
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# #### Answer the following questions:
#
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer:** 4
#
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer:** No, it 4 which is the same as the other

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Scaled PCA DataFrame

# %%
# Initialize the K-Means model using the best value for k
k_means = KMeans(n_clusters=4,random_state=42)

# %%
# Fit the K-Means model using the PCA data
k_means.fit(scaled_pca)
# Out:
# c:\Users\mackd\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4, random_state=42)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled PCA DataFrame
clustered_pca = kmeans.predict(scaled_pca)

# Print the resulting array of cluster values.
print(clustered_pca)
# Out:
# [8 8 3 3 6 8 4 8 8 0 7 3 3 6 0 0 7 0 8 3 7 8 3 3 3 3 0 7 8 5 0 0 2 0 9 3 1
#  7 0 3 3]
# c:\Users\mackd\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(

# %%
# Create a copy of the scaled PCA DataFrame
pca_scaled_df = pca_data_df.copy()

# Add a new column to the copy of the PCA DataFrame with the predicted clusters

pca_scaled_df["prediction cluster"] = clustered_pca

# Display the copy of the scaled PCA DataFrame
pca_scaled_df
# Out:
#                           pca1      pca2      pca3  prediction cluster
# coin_id
# bitcoin              -0.600667  0.842760  0.461595                   8
# ethereum             -0.458261  0.458466  0.952877                   8
# tether               -0.433070 -0.168126 -0.641752                   3
# ripple               -0.471835 -0.222660 -0.479053                   3
# bitcoin-cash         -1.157800  2.041209  1.859715                   6
# binancecoin          -0.516534  1.388377  0.804071                   8
# chainlink            -0.450711  0.517699  2.846143                   4
# cardano              -0.345600  0.729439  1.478013                   8
# litecoin             -0.649468  0.432165  0.600303                   8
# bitcoin-cash-sv      -0.759014 -0.201200 -0.217653                   0
# crypto-com-chain     -0.248198 -1.376252 -1.462026                   7
# usd-coin             -0.438408 -0.175337 -0.663388                   3
# ...

# %%
# Create a scatter plot using hvPlot by setting
# `x="PC1"` and `y="PC2"`.
# Color the graph points with the labels found using K-Means and
# add the crypto name in the `hover_cols` parameter to identify
# the cryptocurrency represented by each data point.
pca_scaled_df.hvplot.scatter(x="pca1",y="pca2",by="prediction cluster",hover_cols="coin_id")
# Out:
# :NdOverlay   [prediction cluster]
#    :Scatter   [pca1]   (pca2,coin_id)

# %% [markdown]
# ### Visualize and Compare the Results
#
# In this section, you will visually analyze the cluster analysis results by contrasting the outcome with and without using the optimization techniques.

# %%
(elbowcurve_df.hvplot('k','inertia') + pca_elbow_df.hvplot.line('k','inertia'))
# Out:
# :Layout
#    .Curve.I  :Curve   [k]   (inertia)
#    .Curve.II :Curve   [k]   (inertia)

# %%
# Composite plot to contrast the clusters
(crypto_cluster_df.hvplot.scatter(x="price_change_percentage_24h",y="price_change_percentage_7d",by='Clusters')+ pca_scaled_df.hvplot.scatter(x="pca1",y="pca2",by="prediction cluster",hover_cols="coin_id"))
# Out:
# :Layout
#    .NdOverlay.I  :NdOverlay   [Clusters]
#       :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d)
#    .NdOverlay.II :NdOverlay   [prediction cluster]
#       :Scatter   [pca1]   (pca2,coin_id)

# %% [markdown]
# #### Answer the following question:
#
#   * **Question:** After visually analyzing the cluster analysis results, what is the impact of using fewer features to cluster the data using K-Means?
#
#   * **Answer:** Honestly, I am not sure. I do not think I did something right with K-means...I got 8 clusters so it looks to me like it did not make fewer clusters it made more clusters. While I would love to figure out why and how to fix this, I have to have this in by Sunday.
